# %% [markdown]
# # Import Dataset

# %%
import pandas as pd

# Mengimpor data dari file 
data = pd.read_excel('C:/Users/zamig/Downloads/Hematological data of children 6-59 months who visited Hawassa University Comprehensive and Specialist.xlsx')
data
# Out:
#           Date  Age_Years     Sex Age_years_dichotomized  \
# 0     20180104        4.0    Male    Two years and above
# 1     20180824        1.0    Male       Under two years
# 2     20170815        1.0    Male       Under two years
# 3     20170821        1.0    Male       Under two years
# 4     20180713        1.0    Male       Under two years
# ...        ...        ...     ...                    ...
# 4734  20170614        2.0  Female    Two years and above
# 4735  20171005        1.0  Female       Under two years
# 4736  20180519        3.0  Female    Two years and above
# 4737  20181016        2.0  Female    Two years and above
# 4738  20170717        1.0  Female       Under two years
#
#      Age_months_pentachotomized  RBC_count_in_Millions  \
# 0                  48-59 months                  5.300
# 1                  12-23 months                  6.060
# 2                  12-23 months                  5.830
# 3                  12-23 months                  7.280
# ...

# %%
# Mengubah kolom 'Date' ke format tanggal
data['Date'] = pd.to_datetime(data['Date'], format='%Y%m%d')

# %% [markdown]
# # Informasi dalam data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4739 entries, 0 to 4738
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        4739 non-null   datetime64[ns]
#  1   Age_Years                   4739 non-null   float64
#  2   Sex                         4739 non-null   object
#  3   Age_years_dichotomized      4739 non-null   object
#  4   Age_months_pentachotomized  4739 non-null   object
#  5   RBC_count_in_Millions       4739 non-null   float64
#  6   HGB_Alltitude_Adjusted      4739 non-null   float64
#  7   HCT                         4738 non-null   float64
#  8   MCV                         4739 non-null   float64
#  9   MCH                         4739 non-null   float64
#  10  MCHC                        4717 non-null   float64
#  11  RDW                         4739 non-null   float64
#  12  Anaemia                     4739 non-null   object
# ...

# %%
data.describe()
# Out:
#                                 Date    Age_Years  RBC_count_in_Millions  \
# count                           4739  4739.000000            4739.000000
# mean   2018-04-23 10:12:35.096011776     1.948864               4.829882
# min              2017-03-06 00:00:00     0.500000               0.068600
# 25%              2017-12-23 12:00:00     1.000000               4.261000
# 50%              2018-05-24 00:00:00     2.000000               4.898000
# 75%              2018-10-08 00:00:00     3.000000               5.440000
# max              2019-04-24 00:00:00     4.000000              76.200000
# std                              NaN     1.198087               1.968000
#
#        HGB_Alltitude_Adjusted          HCT          MCV          MCH  \
# count             4739.000000  4738.000000  4739.000000  4739.000000
# mean                10.926772    36.899032    78.389534    24.468418
# min                  0.100000     0.679900    12.400000     9.140000
# ...

# %% [markdown]
# # Visualisasi Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#visualisasi data dengan boxplot
plt.figure(figsize=(20,15))
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['Sex'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel Sex')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['Age_years_dichotomized'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel Age (years)_dichotomized')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['Age_months_pentachotomized'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel Age_months_pentachotomized')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['Age_months_pentachotomized'].value_counts()

# Plotting bar plot dengan jumlah data
plt.figure(figsize=(10, 6))
kategori_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Kategori Age (Months)')
plt.ylabel('Jumlah Data')
plt.title('Bar Plot: Variabel Age_months_pentachotomized')
plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
plt.grid(axis='y')  # Menampilkan grid hanya pada sumbu y
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['Anaemia'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel Anaemia')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['RBC_size'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel RBC_size')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['RBC_color'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel RBC_color')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['RBC_Hgb_Conc'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel RBC_Hgb_conc')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['RBC_Width'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel RBC_Width')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['ID'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel ID')
plt.show()

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah data untuk setiap kategori pada variabel kategorik
kategori_counts = data['IDA'].value_counts()

# Plotting pie chart dengan jumlah data dan persentase
plt.figure(figsize=(8, 8))
plt.pie(kategori_counts, labels=[f'{label} ({count} data, {count / sum(kategori_counts) * 100:.1f}%)' for label, count in zip(kategori_counts.index, kategori_counts)],
        autopct='', startangle=140)
plt.title('Pie Chart Variabel IDA')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Memilih kolom-kolom yang ingin dilihat hubungannya dengan Age_Year
selected_columns = ['Age_Years', 'RBC_count_in_Millions', 'HGB_Alltitude_Adjusted', 'HCT', 'MCV', 'MCH', 'MCHC', 'RDW']
selected_data = data[selected_columns]

# Membuat pair plot untuk melihat hubungan antar variabel
sns.pairplot(selected_data)
plt.suptitle('Pair Plot: Hubungan Antara Age_Year dengan Variabel Lainnya', y=1.02)
plt.show()
# Out:
# C:\Users\zamig\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zamig\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\zamig\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Cek Missing Value pada data

# %%
#cek missing value
data.isnull().sum()
# Out:
# Date                           0
# Age_Years                      0
# Sex                            0
# Age_years_dichotomized         0
# Age_months_pentachotomized     0
# RBC_count_in_Millions          0
# HGB_Alltitude_Adjusted         0
# HCT                            1
# MCV                            0
# MCH                            0
# MCHC                          22
# RDW                            0
# Anaemia                        0
# RBC_size                       0
# RBC_color                      0
# RBC_Hgb_Conc                  22
# RBC_Width                      0
# ID                             0
# IDA                            0
# dtype: int64

# %%
# Menampilkan missing value dalam DataFrame
missing_values = data[data.isnull().any(axis=1)]
print("Missing Value dalam DataFrame:")
missing_values
# Out:
# Missing Value dalam DataFrame:
#            Date  Age_Years     Sex Age_years_dichotomized  \
# 3084 2018-01-15   0.500000    Male       Under two years
# 3661 2018-11-15   0.750000    Male       Under two years
# 3662 2018-01-30   3.000000    Male    Two years and above
# 3663 2018-05-11   1.000000    Male       Under two years
# 3664 2018-05-22   4.000000    Male    Two years and above
# 3665 2018-01-15   1.000000    Male       Under two years
# 3666 2018-05-12   1.000000    Male       Under two years
# 3667 2018-05-08   2.000000    Male    Two years and above
# 3668 2018-05-16   3.000000    Male    Two years and above
# 3669 2018-01-12   2.000000    Male    Two years and above
# 3670 2018-04-11   0.583333    Male       Under two years
# 3671 2018-05-08   3.000000    Male    Two years and above
# 3672 2018-03-21   1.000000    Male       Under two years
# 3673 2018-03-16   2.000000    Male    Two years and above
# 4574 2018-03-16   3.000000  Female    Two years and above
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Memeriksa distribusi kolom 'HCT' menggunakan histogram
plt.figure(figsize=(8, 6))
plt.hist(data['HCT'], bins=10, edgecolor='black', density=True, alpha=0.7, label='Distribusi Data')

# Menghitung mean dan standard deviation
mean_hct = data['HCT'].mean()
std_hct = data['HCT'].std()

# Menghitung distribusi normal
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean_hct, std_hct)
plt.plot(x, p, 'k', linewidth=2, label='Distribusi Normal')

plt.xlabel('HCT')
plt.ylabel('Densitas')
plt.title('Distribusi Kolom HCT')
plt.legend()
plt.grid(True)
plt.show()

# %%
from scipy import stats

data1 = data.dropna(subset=['HCT'], inplace=False)

statistic, p_value = stats.kstest(data1['HCT'], 'norm')
if p_value > 0.05:
    print("The data follows a normal distribution.")
else:
    print("The data does not follow a normal distribution.")

print("p-value = ", p_value)
# Out:
# The data does not follow a normal distribution.
# p-value =  0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Memeriksa distribusi kolom 'HCT' menggunakan histogram
plt.figure(figsize=(8, 6))
plt.hist(data['MCHC'].dropna(), bins=10, edgecolor='black', density=True, alpha=0.7, label='Distribusi Data')

# Menghitung mean dan standard deviation
mean_hct = data['MCHC'].mean()
std_hct = data['MCHC'].std()

# Menghitung distribusi normal
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean_hct, std_hct)
plt.plot(x, p, 'k', linewidth=2, label='Distribusi Normal')

plt.xlabel('MCHC')
plt.ylabel('Densitas')
plt.title('Distribusi Kolom MCHC')
plt.legend()
plt.grid(True)
plt.show()

# %%
from scipy import stats

dataa = data.dropna(subset=['MCHC'], inplace=False)

from scipy import stats
statistic, p_value = stats.kstest(dataa['MCHC'], 'norm')
if p_value > 0.05:
    print("The data follows a normal distribution.")
else:
    print("The data does not follow a normal distribution.")

    print("p-value = ", p_value)
# Out:
# The data does not follow a normal distribution.
# p-value =  0.0

# %%
import pandas as pd

# Mengganti missing values HCT dengan nilai median
median_HCT = data['HCT'].median()
data['HCT'].fillna(median_HCT, inplace=True)

# Mengganti missing values MCHC dengan nilai median
median_MCHC = data['MCHC'].median()
data['MCHC'].fillna(median_MCHC, inplace=True)
# Out:
# C:\Users\zamig\AppData\Local\Temp\ipykernel_9916\1815677670.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['HCT'].fillna(median_HCT, inplace=True)
# C:\Users\zamig\AppData\Local\Temp\ipykernel_9916\1815677670.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import pandas as pd

# Fungsi untuk mengganti missing value berdasarkan kondisi MCHC
def replace_rbc_hgb_conc(mchc_value):
    if mchc_value is None:
        return None  # Biarkan missing value pada 'RBC_Hgb_Conc' jika MCHC juga missing
    elif mchc_value < 31:
        return 'Low MCHC'
    elif 31 <= mchc_value <= 35:
        return 'Normal MCHC'
    else:
        return 'High MCHC'

# Mengganti missing value dalam kolom 'RBC_Hgb_Conc' dengan fungsi yang ditentukan
data['RBC_Hgb_Conc'] = data['MCHC'].apply(replace_rbc_hgb_conc)

# Menampilkan DataFrame setelah mengganti missing value
print("DataFrame setelah mengganti missing value:")
data

# Menampilkan baris-baris yang diminta
indices = [3084] + list(range(3661, 3674)) + list(range(4574, 4581)) + [4707]
selected_rows = data.iloc[indices]
selected_rows
# Out:
# DataFrame setelah mengganti missing value:
#            Date  Age_Years     Sex Age_years_dichotomized  \
# 3084 2018-01-15   0.500000    Male       Under two years
# 3661 2018-11-15   0.750000    Male       Under two years
# 3662 2018-01-30   3.000000    Male    Two years and above
# 3663 2018-05-11   1.000000    Male       Under two years
# 3664 2018-05-22   4.000000    Male    Two years and above
# 3665 2018-01-15   1.000000    Male       Under two years
# 3666 2018-05-12   1.000000    Male       Under two years
# 3667 2018-05-08   2.000000    Male    Two years and above
# 3668 2018-05-16   3.000000    Male    Two years and above
# 3669 2018-01-12   2.000000    Male    Two years and above
# 3670 2018-04-11   0.583333    Male       Under two years
# 3671 2018-05-08   3.000000    Male    Two years and above
# 3672 2018-03-21   1.000000    Male       Under two years
# 3673 2018-03-16   2.000000    Male    Two years and above
# ...

# %%
data.isnull().sum()
# Out:
# Date                          0
# Age_Years                     0
# Sex                           0
# Age_years_dichotomized        0
# Age_months_pentachotomized    0
# RBC_count_in_Millions         0
# HGB_Alltitude_Adjusted        0
# HCT                           0
# MCV                           0
# MCH                           0
# MCHC                          0
# RDW                           0
# Anaemia                       0
# RBC_size                      0
# RBC_color                     0
# RBC_Hgb_Conc                  0
# RBC_Width                     0
# ID                            0
# IDA                           0
# dtype: int64

# %% [markdown]
# # Duplicate Data

# %%
# Mengecek data duplikat
duplikat = data.duplicated()

# Menampilkan data yang duplikat
data_duplikat = data[duplikat]

# Menampilkan data yang duplikat
data_duplikat
# Out:
#            Date  Age_Years     Sex Age_years_dichotomized  \
# 1065 2018-11-03        2.0    Male    Two years and above
# 1806 2018-10-25        1.0  Female       Under two years
# 2379 2018-05-07        4.0  Female    Two years and above
# 3811 2018-11-14        2.0    Male    Two years and above
#
#      Age_months_pentachotomized  RBC_count_in_Millions  \
# 1065               24-35 months                  5.040
# 1806               12-23 months                  4.450
# 2379               48-59 months                  4.417
# 3811               24-35 months                  1.320
#
#       HGB_Alltitude_Adjusted    HCT    MCV    MCH   MCHC    RDW     Anaemia  \
# 1065                   11.50  36.80   73.0  23.80  32.60  16.20  Non-anemic
# 1806                   11.30  39.80   88.3  26.50  30.00  20.20  Non-anemic
# 2379                   11.05  34.67   78.5  26.16  33.32  13.57  Non-anemic
# 3811                    3.70  13.90  105.3  31.80  30.20  31.50      Anemic
#
# ...

# %%
data2 = data.drop_duplicates()

# %%
data2
# Out:
#            Date  Age_Years     Sex Age_years_dichotomized  \
# 0    2018-01-04        4.0    Male    Two years and above
# 1    2018-08-24        1.0    Male       Under two years
# 2    2017-08-15        1.0    Male       Under two years
# 3    2017-08-21        1.0    Male       Under two years
# 4    2018-07-13        1.0    Male       Under two years
# ...         ...        ...     ...                    ...
# 4734 2017-06-14        2.0  Female    Two years and above
# 4735 2017-10-05        1.0  Female       Under two years
# 4736 2018-05-19        3.0  Female    Two years and above
# 4737 2018-10-16        2.0  Female    Two years and above
# 4738 2017-07-17        1.0  Female       Under two years
#
#      Age_months_pentachotomized  RBC_count_in_Millions  \
# 0                  48-59 months                  5.300
# 1                  12-23 months                  6.060
# 2                  12-23 months                  5.830
# ...

# %% [markdown]
# # Transpose Data

# %%
data2.transpose()
# Out:
#                                            0                    1     \
# Date                        2018-01-04 00:00:00  2018-08-24 00:00:00
# Age_Years                                   4.0                  1.0
# Sex                                        Male                 Male
# Age_years_dichotomized      Two years and above     Under two years
# Age_months_pentachotomized         48-59 months         12-23 months
# RBC_count_in_Millions                       5.3                 6.06
# HGB_Alltitude_Adjusted                     14.4                 11.5
# HCT                                        48.8                 43.3
# MCV                                        91.0                 71.5
# MCH                                        27.0                 19.8
# MCHC                                        3.5                 19.8
# RDW                                        19.0                 17.9
# Anaemia                              Non-anemic           Non-anemic
# ...

# %% [markdown]
# # One Hot Encoding

# %%
# Import Library yang akan digunakan
import numpy as np

max_k = 13 # Jumlah kategori paling banyak pada variabel yang akan di encode

# Daftar kolom yang akan dilakukan one-hot encoding
columns_to_encode = ['Age_months_pentachotomized']

# Lakukan one-hot encoding untuk setiap kolom
for col in columns_to_encode:
    top_values = data2[col].value_counts().nlargest(max_k).index
    for value in top_values:
        data2[col + '_' + str(value)] = (data2[col] == value).astype(int)

# Hapus kolom asli yang telah di-encode
data_encoded = data2.drop(columns=columns_to_encode)
data_encoded
# Out:
# C:\Users\zamig\AppData\Local\Temp\ipykernel_9916\2153476413.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2[col + '_' + str(value)] = (data2[col] == value).astype(int)
# C:\Users\zamig\AppData\Local\Temp\ipykernel_9916\2153476413.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2[col + '_' + str(value)] = (data2[col] == value).astype(int)
# C:\Users\zamig\AppData\Local\Temp\ipykernel_9916\2153476413.py:13: SettingWithCopyWarning:
# ...

# %% [markdown]
# # Label Encoding

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

#melabeli data yang ada di variabel kategorik menjadi numerik
data_encoded[['Sex','Age_years_dichotomized','RBC_size', 'RBC_color', 'RBC_Hgb_Conc', 'RBC_Width','Anaemia', 'ID', 'IDA']] = data_encoded[['Sex','Age_years_dichotomized','RBC_size', 'RBC_color', 'RBC_Hgb_Conc', 'RBC_Width','Anaemia', 'ID', 'IDA']].apply(LabelEncoder().fit_transform)

#view udpated DataFr
data_encoded
# Out:
#            Date  Age_Years  Sex  Age_years_dichotomized  \
# 0    2018-01-04        4.0    1                       0
# 1    2018-08-24        1.0    1                       1
# 2    2017-08-15        1.0    1                       1
# 3    2017-08-21        1.0    1                       1
# 4    2018-07-13        1.0    1                       1
# ...         ...        ...  ...                     ...
# 4734 2017-06-14        2.0    0                       0
# 4735 2017-10-05        1.0    0                       1
# 4736 2018-05-19        3.0    0                       0
# 4737 2018-10-16        2.0    0                       0
# 4738 2017-07-17        1.0    0                       1
#
#       RBC_count_in_Millions  HGB_Alltitude_Adjusted    HCT     MCV    MCH  \
# 0                     5.300                  14.400  48.80   91.00  27.00
# 1                     6.060                  11.500  43.30   71.50  19.80
# ...

# %% [markdown]
# # Feature Sellection

# %%
# Feature selection data
columns_to_drop = ['Date','RBC_size', 'RBC_color', 'RBC_Hgb_Conc', 
                   'RBC_Width','Age_years_dichotomized','Age_months_pentachotomized_12-23 months',
                   'Age_months_pentachotomized_24-35 months', 'Age_months_pentachotomized_6-11 months', 
                   'Age_months_pentachotomized_36-47 months', 'Age_months_pentachotomized_48-59 months',
                   'ID', 'IDA']
feature1 = data_encoded.drop(columns=columns_to_drop)
# Cetak daftar nama kolom sebelum melakukan drop
feature1
# Out:
#       Age_Years  Sex  RBC_count_in_Millions  HGB_Alltitude_Adjusted    HCT  \
# 0           4.0    1                  5.300                  14.400  48.80
# 1           1.0    1                  6.060                  11.500  43.30
# 2           1.0    1                  5.830                  11.600  38.50
# 3           1.0    1                  7.280                  12.000  17.10
# 4           1.0    1                  8.200                  14.300  62.70
# ...         ...  ...                    ...                     ...    ...
# 4734        2.0    0                  1.870                   5.360  17.00
# 4735        1.0    0                  2.770                   6.890  21.00
# 4736        3.0    0                  1.685                   3.921  11.98
# 4737        2.0    0                  1.365                   3.990  12.12
# 4738        1.0    0                  0.930                   4.040   9.60
#
#          MCV    MCH   MCHC    RDW  Anaemia
# ...

# %% [markdown]
# # Feature Scalling

# %%
# Import library
from sklearn.preprocessing import MinMaxScaler

# List kolom-kolom yang akan di-transformasi dengan MinMaxScaler
columns_to_scale = ['Age_Years', 'RBC_count_in_Millions', 'HGB_Alltitude_Adjusted', 'HCT', 'MCV', 'MCH', 'MCHC', 'RDW']

# Inisialisasi MinMaxScaler
scaler = MinMaxScaler()

# Melakukan transformasi MinMaxScaler pada kolom-kolom tersebut secara bersamaan
scaled_data = feature1.copy()
scaled_data[columns_to_scale] = scaler.fit_transform(data_encoded[columns_to_scale])

# Menampilkan DataFrame baru setelah transformasi MinMaxScaler
scaled_data
# Out:
#       Age_Years  Sex  RBC_count_in_Millions  HGB_Alltitude_Adjusted       HCT  \
# 0      1.000000    1               0.068715                0.567460  0.551077
# 1      0.142857    1               0.078698                0.452381  0.488090
# 2      0.142857    1               0.075677                0.456349  0.433120
# 3      0.142857    1               0.094723                0.472222  0.188045
# 4      0.142857    1               0.106807                0.563492  0.710261
# ...         ...  ...                    ...                     ...       ...
# 4734   0.428571    0               0.023662                0.208730  0.186900
# 4735   0.142857    0               0.035483                0.269444  0.232708
# 4736   0.714286    0               0.021232                0.151627  0.129410
# 4737   0.428571    0               0.017028                0.154365  0.131013
# 4738   0.142857    0               0.011315                0.156349  0.102154
#
# ...

# %%
#visualisasi data dengan boxplot

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,10))
sns.boxplot(data=scaled_data[columns_to_scale])
# Out:
# <Axes: >

# %% [markdown]
# # Splitting Data

# %%
from sklearn.model_selection import train_test_split

X= feature1.drop(columns='Anaemia')
y= feature1.Anaemia

X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, stratify=y, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3314, 9), (1421, 9), (3314,), (1421,))

# %% [markdown]
# # Build Model Klasifikasi

# %% [markdown]
# ## Random Forest

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Inisialisasi model Random Forest Classifier
model3 = RandomForestClassifier()

# Melakukan fitting pada data training
model3.fit(X_train, y_train)

# Melakukan prediksi pada data training
y_train_pred = model3.predict(X_train)

# Melakukan prediksi pada data test
y_test_pred = model3.predict(X_test)

# Menghitung akurasi pada data training
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Akurasi pada data training: ", train_accuracy)

# Menghitung akurasi pada data test
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Akurasi pada data test: ", test_accuracy)
# Out:
# Akurasi pada data training:  1.0
# Akurasi pada data test:  1.0

# %%
# Menyiapkan data untuk plot
accuracies = {
    'Training Accuracy': train_accuracy,
    'Testing Accuracy': test_accuracy
}

# Plot
sns.barplot(x=list(accuracies.keys()), y=list(accuracies.values()))
plt.ylim(0, 1)
plt.title('Training vs Testing Accuracy')
plt.ylabel('Accuracy')
plt.show()
# Out:
# C:\Users\zamig\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
import pickle

fillname11="Coba_lagi_RF_model.sav"
pickle.dump(model3, open(fillname11,"wb"))

# %%
from sklearn.tree import plot_tree

# Pilih salah satu pohon keputusan dari model Random Forest
chosen_tree = model3.estimators_[5]  # Misalnya, pohon keempat dari ensemble

# Plot decision tree
plt.figure(figsize=(15, 10))
plot_tree(chosen_tree, filled=True, feature_names=X_train.columns, class_names=["Class 0", "Class 1"])
plt.title("Decision Tree from Random Forest Classifier")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

cm3 = confusion_matrix(y_test, y_test_pred)

# Plotting heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm3, annot=True, cmap='Blues', fmt='d', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Random Forest')
plt.show()

# %% [markdown]
# # Build Model Klastering

# %%
scaled_data
# Out:
#       Age_Years  Sex  RBC_count_in_Millions  HGB_Alltitude_Adjusted       HCT  \
# 0      1.000000    1               0.068715                0.567460  0.551077
# 1      0.142857    1               0.078698                0.452381  0.488090
# 2      0.142857    1               0.075677                0.456349  0.433120
# 3      0.142857    1               0.094723                0.472222  0.188045
# 4      0.142857    1               0.106807                0.563492  0.710261
# ...         ...  ...                    ...                     ...       ...
# 4734   0.428571    0               0.023662                0.208730  0.186900
# 4735   0.142857    0               0.035483                0.269444  0.232708
# 4736   0.714286    0               0.021232                0.151627  0.129410
# 4737   0.428571    0               0.017028                0.154365  0.131013
# 4738   0.142857    0               0.011315                0.156349  0.102154
#
# ...

# %%
import pandas as pd

# Filter data berdasarkan kolom 'Anaemia' yang tergolong Anemic
data_kluster = scaled_data[scaled_data['Anaemia'] == 0]

# Tampilkan data yang tergolong Anemic
data_kluster
# Out:
#       Age_Years  Sex  RBC_count_in_Millions  HGB_Alltitude_Adjusted       HCT  \
# 2622   0.071429    1               0.107990                0.428571  0.651856
# 2623   0.142857    1               0.081062                0.420635  0.486945
# 2624   1.000000    1               0.062936                0.420635  0.475493
# 2625   0.023810    1               0.078961                0.392857  0.450298
# 2626   0.142857    1               0.078829                0.400794  0.458315
# ...         ...  ...                    ...                     ...       ...
# 4734   0.428571    0               0.023662                0.208730  0.186900
# 4735   0.142857    0               0.035483                0.269444  0.232708
# 4736   0.714286    0               0.021232                0.151627  0.129410
# 4737   0.428571    0               0.017028                0.154365  0.131013
# 4738   0.142857    0               0.011315                0.156349  0.102154
#
# ...

# %%
dkluster = data_kluster.drop(columns=['Age_Years','Sex','Anaemia'])
dkluster
# Out:
#       RBC_count_in_Millions  HGB_Alltitude_Adjusted       HCT       MCV  \
# 2622               0.107990                0.428571  0.651856  0.481450
# 2623               0.081062                0.420635  0.486945  0.478921
# 2624               0.062936                0.420635  0.475493  0.629005
# 2625               0.078961                0.392857  0.450298  0.450253
# 2626               0.078829                0.400794  0.458315  0.461214
# ...                     ...                     ...       ...       ...
# 4734               0.023662                0.208730  0.186900  0.661046
# 4735               0.035483                0.269444  0.232708  0.533727
# 4736               0.021232                0.151627  0.129410  0.495025
# 4737               0.017028                0.154365  0.131013  0.643845
# 4738               0.011315                0.156349  0.102154  0.768971
#
#            MCH      MCHC       RDW
# 2622  0.038397  0.242515  0.133811
# ...

# %% [markdown]
# ### K-Means

# %%
import numpy as np

datklus = np.asarray(dkluster)
print(datklus)
# Out:
# [[0.10798961 0.42857143 0.65185564 ... 0.03839677 0.24251497 0.13381123]
#  [0.08106248 0.42063492 0.48694516 ... 0.07376221 0.33532934 0.24014337]
#  [0.06293592 0.42063492 0.47549304 ... 0.11670596 0.33682635 0.05615293]
#  ...
#  [0.02123171 0.15162698 0.12941007 ... 0.14398787 0.5        0.16367981]
#  [0.01702845 0.15436508 0.13101336 ... 0.19998316 0.50224551 0.25017921]
#  [0.01131465 0.15634921 0.10215403 ... 0.33395083 0.64820359 0.37753883]]

# %%
plt.scatter(datklus[:, 0], datklus[:, 1], s=10)
plt.axis('equal');

# %%
from sklearn.cluster import KMeans
score = []
for k in range(2, 6):
    kmeans = KMeans(n_clusters=k)
    label = kmeans.fit_predict(datklus)
    
    score.append(kmeans.inertia_)
plt.figure(figsize=(10,5))
plt.plot(range(2, 6), score)
plt.ylabel('Inertia')
plt.xlabel('n_clusters')
# Out:
# Text(0.5, 0, 'n_clusters')

# %%
from sklearn.metrics import silhouette_score
score = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k)
    label = kmeans.fit_predict(datklus)
    
    siluet = silhouette_score(datklus, label, metric='euclidean')
    score.append(siluet)
    
plt.figure(figsize=(10,5))
plt.plot(range(2, 11), score)
plt.ylabel('Silhouette')
plt.xlabel('n_clusters')
# Out:
# Text(0.5, 0, 'n_clusters')

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Inisialisasi KMeans dan prediksi kluster
kmeans1 = KMeans(n_clusters=2, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred1 = kmeans1.fit_predict(datklus)

# Menyimpan indeks DataFrame sebelum ditambahkan kolom kluster
index_data_kluster = data_kluster.index

# Menambahkan kolom kluster dengan label yang sesuai dengan indeks
data_kluster1 = data_kluster.copy()
data_kluster1['Cluster K-Means'] = pd.Series(pred1, index=index_data_kluster)

# Cek DataFrame setelah menambahkan kolom kluster
data_kluster1
# Out:
#       Age_Years  Sex  RBC_count_in_Millions  HGB_Alltitude_Adjusted       HCT  \
# 2622   0.071429    1               0.107990                0.428571  0.651856
# 2623   0.142857    1               0.081062                0.420635  0.486945
# 2624   1.000000    1               0.062936                0.420635  0.475493
# 2625   0.023810    1               0.078961                0.392857  0.450298
# 2626   0.142857    1               0.078829                0.400794  0.458315
# ...         ...  ...                    ...                     ...       ...
# 4734   0.428571    0               0.023662                0.208730  0.186900
# 4735   0.142857    0               0.035483                0.269444  0.232708
# 4736   0.714286    0               0.021232                0.151627  0.129410
# 4737   0.428571    0               0.017028                0.154365  0.131013
# 4738   0.142857    0               0.011315                0.156349  0.102154
#
# ...

# %%
cluster_counts = data_kluster1['Cluster K-Means'].value_counts()

# Tampilkan jumlah anggota dalam setiap klaster
print(cluster_counts)
# Out:
# Cluster K-Means
# 0    1684
# 1     432
# Name: count, dtype: int64

# %%
plt.scatter(datklus[pred1==0,0],datklus[pred1==0,1],
            s=10,c='red',label='cluster 1')
plt.scatter(datklus[pred1==1,0],datklus[pred1==1,1],
            s=10,c='blue',label='cluster 2')
plt.scatter(kmeans1.cluster_centers_[:,0],
           kmeans1.cluster_centers_[:,1], s=100, c="black")
plt.title("hasil klaster")
plt.legend()
plt.show()

# %%
from sklearn.metrics import silhouette_score
print(f'Silhouette Score: {silhouette_score(datklus, pred1)}')
# Out:
# Silhouette Score: 0.40971941613382445

# %% [markdown]
# ## K-Means with PCA

# %%
import pandas as pd

# Membuat matriks korelasi
korelasi_matrix = dkluster.corr()

# Menampilkan matriks korelasi
korelasi_matrix
# Out:
#                         RBC_count_in_Millions  HGB_Alltitude_Adjusted  \
# RBC_count_in_Millions                1.000000                0.407263
# HGB_Alltitude_Adjusted               0.407263                1.000000
# HCT                                  0.480618                0.905988
# MCV                                 -0.359994               -0.068182
# MCH                                 -0.327626               -0.050924
# MCHC                                -0.161741                0.213452
# RDW                                 -0.131354               -0.290641
#
#                              HCT       MCV       MCH      MCHC       RDW
# RBC_count_in_Millions   0.480618 -0.359994 -0.327626 -0.161741 -0.131354
# HGB_Alltitude_Adjusted  0.905988 -0.068182 -0.050924  0.213452 -0.290641
# HCT                     1.000000 -0.181920 -0.276421 -0.117584 -0.232610
# MCV                    -0.181920  1.000000  0.688488  0.280498  0.127789
# ...

# %%
korpca = np.array(korelasi_matrix)
print(korpca)
# Out:
# [[ 1.          0.40726334  0.48061758 -0.35999438 -0.3276261  -0.16174137
#   -0.13135387]
#  [ 0.40726334  1.          0.90598797 -0.06818237 -0.05092371  0.21345161
#   -0.29064133]
#  [ 0.48061758  0.90598797  1.         -0.18192035 -0.27642119 -0.11758378
#   -0.23260977]
#  [-0.35999438 -0.06818237 -0.18192035  1.          0.68848768  0.28049805
#    0.12778887]
#  [-0.3276261  -0.05092371 -0.27642119  0.68848768  1.          0.48707155
#    0.01438621]
#  [-0.16174137  0.21345161 -0.11758378  0.28049805  0.48707155  1.
#   -0.12954957]
#  [-0.13135387 -0.29064133 -0.23260977  0.12778887  0.01438621 -0.12954957
#    1.        ]]

# %%
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd

# Inisialisasi PCA dengan jumlah komponen utama yang diinginkan
pca = PCA(n_components=3)
pca.fit(korpca)

# Eigenvalues
eigenvalues = pca.explained_variance_

# Variance Proportion
variance_proportion = pca.explained_variance_ratio_

# Membulatkan variance proportion menjadi 2 angka di belakang koma
variance_proportion = np.round(variance_proportion, 2)

# Cumulative Variance Proportion
cumulative_variance_proportion = np.cumsum(variance_proportion)

# Membulatkan cumulative variance proportion menjadi 2 angka di belakang koma
cumulative_variance_proportion = np.round(cumulative_variance_proportion, 2)

# Menyimpan hasil dalam DataFrame
result_df = pd.DataFrame({
    'Eigenvalues': eigenvalues,
    'Variance Proportion': variance_proportion,
    'Cumulative Variance Proportion': cumulative_variance_proportion
}, index=['PC1', 'PC2', 'PC3'])

print(result_df)
# Out:
#      Eigenvalues  Variance Proportion  Cumulative Variance Proportion
# PC1     1.179592                 0.70                            0.70
# PC2     0.347132                 0.21                            0.91
# PC3     0.090407                 0.05                            0.96

# %%
import numpy as np

datklus = np.asarray(dkluster)
print(datklus)
# Out:
# [[0.10798961 0.42857143 0.65185564 ... 0.03839677 0.24251497 0.13381123]
#  [0.08106248 0.42063492 0.48694516 ... 0.07376221 0.33532934 0.24014337]
#  [0.06293592 0.42063492 0.47549304 ... 0.11670596 0.33682635 0.05615293]
#  ...
#  [0.02123171 0.15162698 0.12941007 ... 0.14398787 0.5        0.16367981]
#  [0.01702845 0.15436508 0.13101336 ... 0.19998316 0.50224551 0.25017921]
#  [0.01131465 0.15634921 0.10215403 ... 0.33395083 0.64820359 0.37753883]]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=1)
pca.fit(datklus)
PCA_ds = pd.DataFrame(pca.transform(datklus), columns=(["col1"]))
PCA_ds
# Out:
#           col1
# 0    -0.270685
# 1    -0.128202
# 2    -0.096402
# 3    -0.143491
# 4    -0.153050
# ...        ...
# 2111  0.245353
# 2112  0.101996
# 2113  0.226088
# 2114  0.336545
# 2115  0.487368
#
# [2116 rows x 1 columns]

# %%
score = []
for k in range(2, 6):
    kmeans2 = KMeans(n_clusters=k)
    pred2 = kmeans2.fit_predict(PCA_ds)
    
    score.append(kmeans2.inertia_)
plt.figure(figsize=(10,5))
plt.plot(range(2, 6), score)
plt.ylabel('Inertia')
plt.xlabel('n_clusters')
# Out:
# Text(0.5, 0, 'n_clusters')

# %%
from sklearn.metrics import silhouette_score
score = []
for k in range(2, 11):
    kmeans2 = KMeans(n_clusters=k)
    pred2 = kmeans2.fit_predict(PCA_ds)
    
    siluet = silhouette_score(PCA_ds, pred2, metric='euclidean')
    score.append(siluet)
    
plt.figure(figsize=(10,5))
plt.plot(range(2, 11), score)
plt.ylabel('Silhouette')

plt.xlabel('n_clusters')
# Out:
# Text(0.5, 0, 'n_clusters')

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Inisialisasi KMeans dengan jumlah klaster yang diinginkan
kmeans2 = KMeans(n_clusters=2, init='k-means++', max_iter=300, n_init=10, random_state=42)
pred2 = kmeans2.fit_predict(PCA_ds)

# Menambahkan kolom klaster ke dalam DataFrame
data_kluster2 = data_kluster.copy()
data_kluster2['Cluster K-Means PCA'] = pred2

# Tampilkan hasil klastering
data_kluster2
# Out:
#       Age_Years  Sex  RBC_count_in_Millions  HGB_Alltitude_Adjusted       HCT  \
# 2622   0.071429    1               0.107990                0.428571  0.651856
# 2623   0.142857    1               0.081062                0.420635  0.486945
# 2624   1.000000    1               0.062936                0.420635  0.475493
# 2625   0.023810    1               0.078961                0.392857  0.450298
# 2626   0.142857    1               0.078829                0.400794  0.458315
# ...         ...  ...                    ...                     ...       ...
# 4734   0.428571    0               0.023662                0.208730  0.186900
# 4735   0.142857    0               0.035483                0.269444  0.232708
# 4736   0.714286    0               0.021232                0.151627  0.129410
# 4737   0.428571    0               0.017028                0.154365  0.131013
# 4738   0.142857    0               0.011315                0.156349  0.102154
#
# ...

# %%
cluster_counts = data_kluster2['Cluster K-Means PCA'].value_counts()

# Tampilkan jumlah anggota dalam setiap klaster
print(cluster_counts)
# Out:
# Cluster K-Means PCA
# 0    1681
# 1     435
# Name: count, dtype: int64

# %%
# Hitung Silhouette Score
silhouette_avg = silhouette_score(PCA_ds, pred2)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.6528381820225942

# %%
import matplotlib.pyplot as plt

pred2 = np.array(pred2)

# Plot cluster 1
plt.scatter(datklus[pred2 == 0, 0], datklus[pred2 == 0, 1],
            s=10, c='red', label='cluster 1')
# Plot cluster 2
plt.scatter(datklus[pred2 == 1, 0], datklus[pred2 == 1, 1],
            s=10, c='blue', label='cluster 2')

# Plot centroids
plt.scatter(kmeans1.cluster_centers_[:, 0],
            kmeans1.cluster_centers_[:, 1], s=100, c='black', label='centroids')

# Menambahkan judul dan legend
plt.title("Hasil klaster")
plt.legend()
plt.show()

# %% [markdown]
# ## Fuzzy Clustering

# %%
pip install scikit-fuzzy
# Out:
# ...
#      ---------------------------------------- 0.0/994.0 kB ? eta -:--:--
#      - ----------------------------------- 41.0/994.0 kB 960.0 kB/s eta 0:00:01
#      ---- --------------------------------- 122.9/994.0 kB 1.8 MB/s eta 0:00:01
#      -------------- ----------------------- 368.6/994.0 kB 2.5 MB/s eta 0:00:01
#      ------------------------ ------------- 634.9/994.0 kB 3.3 MB/s eta 0:00:01
#      ------------------------------ ------- 798.7/994.0 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 994.0/994.0 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894087 sha256=50194fa3bcfffd7b7ef853920834df89f7a06f1fa3e4dd59ddb3b0f7642415cd
#   Stored in directory: c:\users\zamig\appdata\local\pip\cache\wheels\b1\67\d1\6c29aeb1cd2d36447ad5b0de027580b8894aff702a9b50041e
# ...

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define the number of clusters
n_clusters = 2
 
# Apply fuzzy c-means clustering
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    datklus.T, n_clusters, 2, error=0.005, maxiter=1000, init=None
)
 
# Predict cluster membership for each data point
pred3 = np.argmax(u, axis=0)
 
# Menambahkan kolom klaster ke dalam DataFrame
data_kluster3 = data_kluster.copy()
data_kluster3['Cluster Fuzzy'] = pred3
data_kluster3
# Out:
#       Age_Years  Sex  RBC_count_in_Millions  HGB_Alltitude_Adjusted       HCT  \
# 2622   0.071429    1               0.107990                0.428571  0.651856
# 2623   0.142857    1               0.081062                0.420635  0.486945
# 2624   1.000000    1               0.062936                0.420635  0.475493
# 2625   0.023810    1               0.078961                0.392857  0.450298
# 2626   0.142857    1               0.078829                0.400794  0.458315
# ...         ...  ...                    ...                     ...       ...
# 4734   0.428571    0               0.023662                0.208730  0.186900
# 4735   0.142857    0               0.035483                0.269444  0.232708
# 4736   0.714286    0               0.021232                0.151627  0.129410
# 4737   0.428571    0               0.017028                0.154365  0.131013
# 4738   0.142857    0               0.011315                0.156349  0.102154
#
# ...

# %%
cluster_counts = data_kluster3['Cluster Fuzzy'].value_counts()

# Tampilkan jumlah anggota dalam setiap klaster
print(cluster_counts)
# Out:
# Cluster Fuzzy
# 1    1480
# 0     636
# Name: count, dtype: int64

# %%
# Hitung Silhouette Score
silhouette_avg = silhouette_score(datklus, pred3)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.34860380472532565

# %% [markdown]
# ## Fuzzy with PCA

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# Define the number of clusters
n_clusters = 2
 
# Apply fuzzy c-means clustering
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(
    PCA_ds.T, n_clusters, 2, error=0.005, maxiter=1000, init=None
)
 
# Predict cluster membership for each data point
pred4 = np.argmax(u, axis=0)
 
# Menambahkan kolom klaster ke dalam DataFrame
data_kluster4 = data_kluster.copy()
data_kluster4['Cluster Fuzzy with PCA'] = pred3
data_kluster4
# Out:
#       Age_Years  Sex  RBC_count_in_Millions  HGB_Alltitude_Adjusted       HCT  \
# 2622   0.071429    1               0.107990                0.428571  0.651856
# 2623   0.142857    1               0.081062                0.420635  0.486945
# 2624   1.000000    1               0.062936                0.420635  0.475493
# 2625   0.023810    1               0.078961                0.392857  0.450298
# 2626   0.142857    1               0.078829                0.400794  0.458315
# ...         ...  ...                    ...                     ...       ...
# 4734   0.428571    0               0.023662                0.208730  0.186900
# 4735   0.142857    0               0.035483                0.269444  0.232708
# 4736   0.714286    0               0.021232                0.151627  0.129410
# 4737   0.428571    0               0.017028                0.154365  0.131013
# 4738   0.142857    0               0.011315                0.156349  0.102154
#
# ...

# %%
cluster_counts = data_kluster4['Cluster Fuzzy with PCA'].value_counts()

# Tampilkan jumlah anggota dalam setiap klaster
print(cluster_counts)

# Hitung Silhouette Score
silhouette_avg = silhouette_score(datklus, pred4)
print("Silhouette Score:", silhouette_avg)
# Out:
# Cluster Fuzzy with PCA
# 1    1480
# 0     636
# Name: count, dtype: int64
# Silhouette Score: 0.39234835319114375
